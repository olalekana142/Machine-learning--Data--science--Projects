# %% [markdown]
# <a href="https://www.kaggle.com/code/adebayoolalekan/python-fundamentals?scriptVersionId=202034495" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# Variables
#Data Types
message = "Hello python"

# %% [markdown]
# Variables names can only contain numbers, letters and underscores.
#
# * Spaces are in the creation of a variable.

# %%
fruits ="Orange"
print(fruits)

# %% [markdown]
# ### Data Types

# %%
# Integers
# Floats 
# Strings

# %%
# Basics operations of integers
# + * - /
2  + 3

# %%
pi = 3.14 
5 * pi

# %%
# Float are any numbers that with a decimal point
0.2 * pi

# %%
# A string is just a series of characters.
"this is a string"
'this is also a string'

# %%
name = 'olalekan'
print(name)

# %%
print(name.title())

# %%
new_name = "Timileyin"
print(new_name.upper())

# %% [markdown]
# ### Concatenation

# %%
first_name = "Israel"
last_name = "Ademola"

print(first_name +" " + last_name)

# %%
year = 2024
year + 5

# %%
# str(), int(), float()
year = 2024
print("This year is the year " + str(year))

# %%
num = "35"
int(num) * 5

# %%
pi = "3.142"
5 * float(pi)

# %%
first_name = "Israel"
last_name = "Ademola"

print("My first name is " + first_name + " My last name is " + last_name)

# %% [markdown]
# ### Comments

# %%
#This is a comment

5 * 6

# %% [markdown]
# ### Data Structures.
# ### Lists

# %%
#Lists are a collection of items in a particular order
fruits = ["Oranges", "Banana", "Lemon", "Apple"]
print(fruits)

# %%
#Accessing Elements in a List.
print(fruits[0].upper())

# %%
num = [3,4,56,34,23]
print(num[3])

# %%
print(num[-2])

# %%
bio_data = ["Israel","Ademola", "Data Scientist", "Ibadan"]

print("My first name is " + bio_data[0] + " My Last name is " + bio_data[1] + " I am a "+ bio_data[2]+ " I live in "
      + bio_data[3])

# %% [markdown]
# ### Changing ,Adding And Removing From a list

# %%
bio_data[3] = "Lagos"
print(bio_data)

# %%
# append, Insert
bio_data.append("Iyan and Egusi")

# %%
print(bio_data)

# %%
bio_data.insert(2, 20)
print(bio_data)

# %%
# Revoming elements :del, pop(), remove()

del bio_data[5]

# %%
print(bio_data)

# %%
bio_data.pop(2)
bio_data

# %%
bio_data.remove('Data Scientist')
print(bio_data)

# %%
age = [12,3,45,67,12,34]
total = sum(age)
print(total)

# %%
len(age)

# %%
avg =total / len(age)

# %%
print(avg)

# %%
min(age)

# %%
max(age)

# %% [markdown]
# ### Organizing A list

# %%
car = ['bmw', 'audi','toyota', 'lexus']
car.sort()
print(car)

# %%
# sort in reverse
car.sort(reverse=True)
print(car)

# %% [markdown]
# ### Printing  a List in Reverse Order

# %%
# The reverse () method changes the order of a list permanently 
num= [12,14,15,17]
num.reverse()
print(num)

# %%
# Finding The length of a list using the len() FUNCTION
len(car)
len(num)

# %% [markdown]
# ## Tuples

# %% [markdown]
# #### Tuples are used to sotre multiples items like a list.
# #### * The major difference is that they are in order and unchangeable
# #### Tuples are written with round brackets.

# %%
cars =("audi", "benz","Lexus")
cars[::-1]

# %%
bio = ('Ade','08123',"Challenge", 40)

# %%
bio[0].upper()

# %%
bio[2]

# %% [markdown]
# ## Dictionary

# %% [markdown]
# #### A Python dictionary is a data structure that stores the value in key: value pairs.
# #### Dictionaries in Python is a data structure, used to store values in key: value format. This makes it different from lists, tuples, and arrays as in a dictionary each key has an associated value.

# %%
bio = {"name":"Lekan", "Address":"Challenge","phone no":'08123'}
print(bio)

# %%
bio['name']

# %%
bio['Address']

# %% [markdown]
# **A dictionary can also be created by the built-in function dict().**

# %%
vehicles = dict({'car':'bmw', 'bus':'toyota', 'lorry':'benz'})

# %%
print(vehicles)

# %%
fruits ={}

# %%
fruits['Orange'] =2
fruits["banana"] ='A bunch'
fruits['Pineapple'] =3

print(fruits)

# %% [markdown]
# Accessing a dictionary is by using the key mapped to the value

# %%
fruits['banana']

# %% [markdown]
# **There is also a method called get() that will also help in accessing the element from a dictionary. This method accepts key as argument and returns the value**

# %%
fruits.get('Orange')

# %%
print(vehicles['car'].upper())

# %% [markdown]
# * List uses square brackets []
# * Tuples uses curve brackets ()
# * Dictionary uses curly brackets {}

# %%
food = {'menu1':'rice & beans', 'menu2':["Iyan & Egusi", "Iyan & Efo", "Iyan & Ewedu"], "menu3":"Beans & Bread"}

# %%
food['menu2'][1]

# %%
# We can delete a key:value pair in our dictionary using del statment
del(food['menu3'])

# %%
food

# %%
food.items()

# %%
food.keys()

# %%
#Updates dictionary with specified key-value pairs
food.update({"menu3":"Beans"})

# %%
food.update({'menu3':"Beans & Bread"})

# %%
print(food)

# %%
food.pop("menu1")

# %%
print(food)

# %% [markdown]
# ## Loops
# ### FOR LOOP

# %%
# For variable in a collection(iterable):
# Do Something
for i in range(5,10,3):
    print(i)
# Out:
# 5
# 8

# %%
fruits = ["Apple","Orange", "Banana"]
for x,y in enumerate(fruits):
    print('I love ', y)
    print(x)
# Out:
# I love  Apple
# 0
# I love  Orange
# 1
# I love  Banana
# 2

# %%
print('I love ', x)
# Out:
# I love  (2, 'Banana')

# %%
# F Strings
bio = ["Adebayo", "08123"]
print(f"My name is {bio[0]} and my phone number is {bio[1]} ")
# Out:
# My name is Adebayo and my phone number is 08123

# %%
grade = ("grade1","grade2", "grade3","grade4")
for i in grade:
    print(f"I have children in {i}")
# Out:
# I have children in grade1
# I have children in grade2
# I have children in grade3
# I have children in grade4

# %%
#Conditional Statements
# If, Else, Elif
# if a condition is met:
# Do a particular instruction
#else:
# Dont do anything or do another particular instruction
# ANd , Or And equals and not equals to.

age =20
if age < 18 :
    print("You are not eligible to vote")
else:
    print("You are eligible")
# Out:
# You are eligible

# %%
age =60
if age < 18:
    print("Your ticket price is #1500")
elif age > 18 and age < 50 :
    print("Your ticket price is #3000")
else:
    print("you are too old to be here")
# Out:
# you are too old to be here

# %%
# Input Function. This is use to get an input from a user
age =int(input("What is your age"))
if age < 18:
    print("Your ticket price is #1500")
elif age > 18 and age < 50 :
    print("Your ticket price is #3000")
else:
    print("you are too old to be here")
# Out:
# What is your age 40
# Your ticket price is #3000

# %%
even_num = []
for i in range(1,10):
    if i % 2 ==0:
        even_num.append(i)
print(even_num)
print(f"The even numbers in this range are {even_num}")
# Out:
# [2, 4, 6, 8]
# The even numbers in this range are [2, 4, 6, 8]

# %% [markdown]
# Exercises On Tuples And Lists

# %%
#The given tuple is a nested tuple. write a Python program to print the value 20.
tuple1 = ("Orange", [10, 20, 30], (5, 15, 25))
tuple1[1][1]
# Out:
# 20

# %%
# Reverse a list in Python
list1 = [100, 200, 300, 400, 500]
list1.reverse()
list1
# Out:
# [500, 400, 300, 200, 100]

# %%
list2 = [100, 200, 300, 400, 500]
list2[::-1]
# Out:
# [500, 400, 300, 200, 100]

# %%
list2
# Out:
# [100, 200, 300, 400, 500]
