# %% [markdown]
# <a href="https://colab.research.google.com/github/olalekana142/projects/blob/master/Major_Commodity_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Commodities are raw materials or agricultural products that can be traded, including gold, Natural Gas, and wheat. From copper to corn, coal to crude oil, commodities are at the heart of life and the lives of billions of people around the world are affected by price fluctuations.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
df = pd.read_csv('/content/commodity 2000-2022.csv')

# %%
df
# Out:
#       Symbol        Date    Open     High      Low   Close  Volume
# 0       Gold  2000-01-04   281.0   281.00   281.00   282.7       4
# 1       Gold  2000-01-05   283.2   283.20   283.20   281.1      16
# 2       Gold  2000-01-06   281.4   281.40   281.40   281.4       0
# 3       Gold  2000-01-07   281.9   281.90   281.90   281.9       0
# 4       Gold  2000-01-10   281.7   281.70   281.70   281.7       0
# ...      ...         ...     ...      ...      ...     ...     ...
# 34153  Wheat  2022-03-25  1957.8  1965.10  1942.60  1954.2  147904
# 34154  Wheat  2022-03-28  1958.7  1959.80  1915.70  1939.8  181367
# 34155  Wheat  2022-03-29  1922.4  1929.40  1888.30  1912.2  128051
# 34156  Wheat  2022-03-30  1918.4  1937.00  1914.50  1933.5   17765
# 34157  Wheat  2022-03-31  1932.5  1932.65  1918.95  1919.7       0
#
# [34158 rows x 7 columns]

# %%
df.value_counts()
# Out:
# Symbol     Date        Open    High     Low      Close   Volume
# Brent Oil  2000-01-04  281.0   281.00   281.00   282.7   4         1
# Nickel     2022-03-25  1957.8  1965.10  1942.60  1954.2  147904    1
# Palladium  2000-01-18  288.6   288.60   288.60   288.6   0         1
#            2000-01-14  283.9   283.90   283.90   283.9   0         1
#            2000-01-13  284.1   284.10   284.10   284.1   0         1
#                                                                   ..
# Gold       2022-03-24  1944.1  1967.20  1937.40  1962.2  181204    1
#            2022-03-23  1920.9  1948.80  1915.60  1937.3  153306    1
#            2022-03-22  1936.1  1939.50  1909.80  1921.5  153282    1
#            2022-03-21  1922.4  1941.80  1917.20  1929.5  146411    1
# Wheat      2022-03-31  1932.5  1932.65  1918.95  1919.7  0         1
# Length: 34158, dtype: int64

# %%
major_list = df["Symbol"].value_counts().reset_index()["index"].tolist()

# %%
major_list
# Out:
# ['Gold', 'Palladium', 'Nickel', 'Brent Oil', 'Natural Gas', 'Wheat']

# %%
df.describe()
# Out:
#                Open          High           Low         Close         Volume
# count  34158.000000  34158.000000  34158.000000  34158.000000   34158.000000
# mean    1049.095990   1052.926784   1044.946756   1052.675588    2871.630950
# std      520.928989    522.991400    518.625896    523.103658   20859.478723
# min      255.000000    255.000000    255.000000    255.100000       0.000000
# 25%      460.100000    460.100000    460.000000    460.100000       5.000000
# 50%     1221.000000   1225.700000   1216.800000   1234.100000      57.000000
# 75%     1406.000000   1409.200000   1403.100000   1415.300000     246.000000
# max     2121.700000   2121.700000   2121.700000   2117.100000  447651.000000

# %%
Gold = df[df.Symbol=='Gold'].reset_index(drop=True)
Gold

# %%
Palladium=df[df.Symbol=='Palladium'].reset_index(drop=True)
Palladium
# Out:
#          Symbol        Date    Open     High      Low   Close  Volume
# 0     Palladium  2000-01-04   281.0   281.00   281.00   282.7       4
# 1     Palladium  2000-01-05   283.2   283.20   283.20   281.1      16
# 2     Palladium  2000-01-06   281.4   281.40   281.40   281.4       0
# 3     Palladium  2000-01-07   281.9   281.90   281.90   281.9       0
# 4     Palladium  2000-01-10   281.7   281.70   281.70   281.7       0
# ...         ...         ...     ...      ...      ...     ...     ...
# 5688  Palladium  2022-03-25  1957.8  1965.10  1942.60  1954.2  147904
# 5689  Palladium  2022-03-28  1958.7  1959.80  1915.70  1939.8  181367
# 5690  Palladium  2022-03-29  1922.4  1929.40  1888.30  1912.2  128051
# 5691  Palladium  2022-03-30  1918.4  1937.00  1914.50  1933.5   17765
# 5692  Palladium  2022-03-31  1932.5  1932.65  1918.95  1919.7       0
#
# [5693 rows x 7 columns]

# %%
Nickel= df[df.Symbol=='Nickel'].reset_index(drop=True)

# %%
Brent_Oil=df[df.Symbol=='Brent Oil'].reset_index(drop=True)

# %%
Natural_Gas= df[df.Symbol=='Natural Gas'].reset_index(drop=True)
Natural_Gas
# Out:
#            Symbol        Date    Open     High      Low   Close  Volume
# 0     Natural Gas  2000-01-04   281.0   281.00   281.00   282.7       4
# 1     Natural Gas  2000-01-05   283.2   283.20   283.20   281.1      16
# 2     Natural Gas  2000-01-06   281.4   281.40   281.40   281.4       0
# 3     Natural Gas  2000-01-07   281.9   281.90   281.90   281.9       0
# 4     Natural Gas  2000-01-10   281.7   281.70   281.70   281.7       0
# ...           ...         ...     ...      ...      ...     ...     ...
# 5688  Natural Gas  2022-03-25  1957.8  1965.10  1942.60  1954.2  147904
# 5689  Natural Gas  2022-03-28  1958.7  1959.80  1915.70  1939.8  181367
# 5690  Natural Gas  2022-03-29  1922.4  1929.40  1888.30  1912.2  128051
# 5691  Natural Gas  2022-03-30  1918.4  1937.00  1914.50  1933.5   17765
# 5692  Natural Gas  2022-03-31  1932.5  1932.65  1918.95  1919.7       0
#
# [5693 rows x 7 columns]

# %%
Wheat= df[df.Symbol=='Wheat'].reset_index(drop=True)

# %%
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
plt.style.use("seaborn-notebook")

# %%
def close_price():
    fig = go.Figure()

    # Add Traces
    fig.add_trace(go.Scatter(x=Gold['Date']
                             , y=Gold['Close']
                             , name='Brent Oil - Close Pricing'
                             #, visible=True
                            ))

    fig.add_trace(go.Scatter(x=Palladium['Date']
                             , y=Palladium['Close']
                             , name='Palladium - Close Pricing'
                             #, visible=True
                            ))

    fig.add_trace(go.Scatter(x=Nickel['Date']
                             , y=Nickel['Close']
                             , name='Nickel - Close Pricing'
                             #, visible=True
                            ))

    fig.add_trace(go.Scatter(x=Brent_Oil['Date']
                             , y=Brent_Oil['Close']
                             , name='Brent Oil - Close Pricing'
                             #, visible=True
                            ))

    fig.add_trace(go.Scatter(x=Natural_Gas['Date']
                             , y=Natural_Gas['Close']
                             , name='Natural Gas - Close Pricing'
                             #, visible=True
                            ))

    fig.add_trace(go.Scatter(x=Wheat['Date']
                             , y=Wheat['Close']
                             , name='Wheat - Close Pricing'
                             #, visible=True
                            ))
    # Add Buttons
    fig.update_layout(
        updatemenus=[
            dict(
                active=0,
                buttons=list([ 

                    dict(label='Gold',
                         method='update',
                         args=[{'visible': [True, True, False, False, False, False, False, False]},
                               {'title': 'Close Pricing (Gold)'}]),

                    dict(label='Palladium',
                         method='update',
                         args=[{'visible': [False, False, True, True, False, False, False, False]},
                               {'title': 'Close Pricing  (Palladium)'}]),


                    dict(label='Nickel',
                         method='update',
                        args=[{'visible': [False,  False, False, False, True, True, False, False]},
                               {'title': 'Close Pricing  (Nickel)'}]),

                    dict(label='Brent Oil',
                         method='update',
                        args=[{'visible': [False,  False, False, False, True, True, False, False]},
                               {'title': 'Close Pricing  (Brent Oil)'}]),

                    dict(label='Natural Gas',
                         method='update',
                        args=[{'visible': [False,  False, False, False, True, True, False, False]},
                               {'title': 'Close Pricing  (Natural Gas)'}]),

                    dict(label='Wheat',
                         method='update',
                        args=[{'visible': [False,  False, False, False, True, True, False, False]},
                               {'title': 'Close Pricing  (Wheat)'}])
                ])
               )
        ])

    # Set slider selection buttons:
    fig.update_xaxes(
        rangeslider_visible=True,
        rangeselector=dict(
            buttons=list([
                dict(count=1, label='6m', step='month', stepmode='backward'),
                dict(count=6, label='1y', step='year', stepmode='backward'),
                dict(count=2, label='2y', step='year',  stepmode='backward'),
                dict(count=5, label='5y', step='year',  stepmode='backward'),
                dict(count=10, label='10y', step='year',  stepmode='backward'),
                dict(count=1, label='YTD',step='year', stepmode='todate')
            ])
        )
    )

    # Set title
    fig.update_layout(title_text='Close Pricing Average')

    # Set x and y-axis titles
    fig.update_xaxes(title_text='Date')
    fig.update_yaxes(title_text='Price ($)')

    fig.show()  
    
close_price()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
def CandleBar():
    # Candlestick charts for cryptocurrencies:
    fig = go.Figure()


    fig.add_trace(go.Candlestick(x=Palladium['Date']
                                 , open=Palladium['Open']
                                 , high=Palladium['High']
                                 , low=Palladium['Low']
                                 , close=Palladium['Close']
                                 , visible = False 
                                )) 

    fig.add_trace(go.Candlestick(x=Nickel['Date']
                                 , open=Nickel['Open']
                                 , high=Nickel['High']
                                 , low=Nickel['Low']
                                 , close=Nickel['Close']
                                 , visible = False 
                                ))

   fig.add_trace(go.Candlestick(x=Brent_Oil['Date']
                                 , open=Brent_Oil['Open']
                                 , high=Brent_Oil['High']
                                 , low=Brent_Oil['Low']
                                 , close=Brent_Oil['Close']
                                 , visible = False 
                                ))  
   fig.add_trace(go.Candlestick(x=Natural_Gas['Date']
                                 , open=Natural_Gas['Open']
                                 , high=Natural_Gas['High']
                                 , low=Natural_Gas['Low']
                                 , close=Natural_Gas['Close']
                                 , visible = False 
                                )) 
    fig.add_trace(go.Candlestick(x=Wheat['Date']
                                 , open=Wheat['Open']
                                 , high=Wheat['High']
                                 , low=Wheat['Low']
                                 , close=Wheat['Close']
                                 , visible = False 
                                ))


    # Add Buttons
    fig.update_layout(
        updatemenus=[
            dict(
                active=0,
                buttons=list([ 

                    dict(label='Gold',
                         method='update',
                         args=[{'visible': [True, False,False, False]},
                               {'title': 'Candlestick chart (Gold)'}]),

                    dict(label='Palladium',
                         method='update',
                         args=[{'visible': [False, True, False, False]},
                               {'title': 'Candlestick chart (Palladium)'}]),

                    dict(label='Brent_Oil',
                         method='update',
                         args=[{'visible': [False,  False, True, False]},
                               {'title': 'Candlestick chart (Brent Oil)'}]),

                    dict(label='Natural_Gas',
                         method='update',
                         args=[{'visible': [False, False, False, True]},
                               {'title': 'Candlestick chart (Natural Gas)'}]),
                    
                    dict(label='Wheat',
                         method='update',
                         args=[{'visible': [False, False, False, True]},
                               {'title': 'Candlestick chart (Wheat)'}]),
                    
                ]),
            )
        ])

    # Set slider selection buttons:
    fig.update_xaxes(
        rangeslider_visible=True,
        rangeselector=dict(
            buttons=list([
                dict(count=6, label='6m', step='month', stepmode='backward'),
                dict(count=1, label='1y', step='year', stepmode='backward'),
                dict(count=5, label='5y', step='year', stepmode='backward'),
                dict(count=1, label='YTD', step='year', stepmode='todate')
            ])
        )
    )


    # Set title
    fig.update_layout(title_text='Candlestick charts for selected cryptocurrency')

    # Set x and y-axis titles
    fig.update_xaxes(title_text='Date')
    fig.update_yaxes(title_text='Price ($)')

    fig.show()
    
CandleBar()
# Out:
#   File "<ipython-input-1-1f6769fde456>", line 22
#     fig.add_trace(go.Candlestick(x=Brent_Oil['Date']
#                                                     ^
# IndentationError: unindent does not match any outer indentation level
