# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
TRAIN = pd.read_csv('Train.csv')

# %%
TEST = pd.read_csv('Test.csv')

# %%
TEST
# Out:
#               ID  Year_of_Birth Education_Level Marital_Status  \
# 0    ID_ZPMABNVX           1954      Graduation         Single
# 1    ID_WFE91NAA           1961      Graduation          Widow
# 2    ID_JV11RBRK           1973           Basic        Married
# 3    ID_6B7SVKY9           1970      Graduation       Together
# 4    ID_GOVUZ545           1959      Graduation       Together
# ..           ...            ...             ...            ...
# 667  ID_1D68PV28           1975      Graduation        Married
# 668  ID_TM6CYFZO           1955      Graduation       Divorced
# 669  ID_VHR666SC           1952             PhD        Married
# 670  ID_O852YAO1           1960      Graduation       Together
# 671  ID_ML5HMWHI           1961          Master        Married
#
#      Disposable_Income  No_of_Kids_in_home  No_of_Teen_in_home Date_Customer  \
# 0              48556.8                   0                   1    11-01-2013
# ...

# %%
TRAIN
# Out:
#                ID  Year_of_Birth Education_Level Marital_Status  \
# 0     ID_4A9AR6FQ           1955      Graduation       Divorced
# 1     ID_X28T3VEK           1958      Graduation       Together
# 2     ID_AWXARH57           1962      Graduation         Single
# 3     ID_FQVZHE81           1979        2n Cycle         Single
# 4     ID_QVLWGPRN           1959      Graduation        Married
# ...           ...            ...             ...            ...
# 1563  ID_XWINUFGG           1970      Graduation        Married
# 1564  ID_GLVIHZLR           1980      Graduation         Single
# 1565  ID_O11VSIJY           1952          Master        Married
# 1566  ID_VS37P6MS           1964             PhD         Single
# 1567  ID_AKHOY7EI           1970      Graduation       Together
#
#       Disposable_Income  No_of_Kids_in_home  No_of_Teen_in_home Date_Customer  \
# 0               77504.4                   1                   1    22-06-2014
# ...

# %%
TRAIN.isnull().sum()
# Out:
# ID                          0
# Year_of_Birth               0
# Education_Level             0
# Marital_Status              0
# Disposable_Income          16
# No_of_Kids_in_home          0
# No_of_Teen_in_home          0
# Date_Customer               0
# Recency                     0
# Discounted_Purchases        0
# WebPurchases                0
# CatalogPurchases            0
# StorePurchases              0
# Amount_on_Wines             0
# Amount_on_Fruits            0
# Amount_on_MeatProducts      0
# Amount_on_FishProducts      0
# Amount_on_SweetProducts     0
# Amount_on_GoldProds         0
# WebVisitsMonth              0
# Cmp3Accepted                0
# Cmp4Accepted                0
# Cmp5Accepted                0
# Cmp1Accepted                0
# Cmp2Accepted                0
# Any_Complain                0
# Response                    0
# dtype: int64

# %%
TEST.isnull().sum()
# Out:
# ID                         0
# Year_of_Birth              0
# Education_Level            0
# Marital_Status             0
# Disposable_Income          8
# No_of_Kids_in_home         0
# No_of_Teen_in_home         0
# Date_Customer              0
# Recency                    0
# Discounted_Purchases       0
# WebPurchases               0
# CatalogPurchases           0
# StorePurchases             0
# Amount_on_Wines            0
# Amount_on_Fruits           0
# Amount_on_MeatProducts     0
# Amount_on_FishProducts     0
# Amount_on_SweetProducts    0
# Amount_on_GoldProds        0
# WebVisitsMonth             0
# Cmp3Accepted               0
# Cmp4Accepted               0
# Cmp5Accepted               0
# Cmp1Accepted               0
# Cmp2Accepted               0
# Any_Complain               0
# dtype: int64

# %%
TRAIN['Disposable_Income'].fillna(TRAIN['Disposable_Income'].mean(), inplace = True)

# %%
TEST['Disposable_Income'].fillna(TEST['Disposable_Income'].mean(), inplace = True)

# %%
TRAIN.isnull().sum()
# Out:
# ID                         0
# Year_of_Birth              0
# Education_Level            0
# Marital_Status             0
# Disposable_Income          0
# No_of_Kids_in_home         0
# No_of_Teen_in_home         0
# Date_Customer              0
# Recency                    0
# Discounted_Purchases       0
# WebPurchases               0
# CatalogPurchases           0
# StorePurchases             0
# Amount_on_Wines            0
# Amount_on_Fruits           0
# Amount_on_MeatProducts     0
# Amount_on_FishProducts     0
# Amount_on_SweetProducts    0
# Amount_on_GoldProds        0
# WebVisitsMonth             0
# Cmp3Accepted               0
# Cmp4Accepted               0
# Cmp5Accepted               0
# Cmp1Accepted               0
# Cmp2Accepted               0
# Any_Complain               0
# Response                   0
# dtype: int64

# %%
TEST.isnull().sum()
# Out:
# ID                         0
# Year_of_Birth              0
# Education_Level            0
# Marital_Status             0
# Disposable_Income          0
# No_of_Kids_in_home         0
# No_of_Teen_in_home         0
# Date_Customer              0
# Recency                    0
# Discounted_Purchases       0
# WebPurchases               0
# CatalogPurchases           0
# StorePurchases             0
# Amount_on_Wines            0
# Amount_on_Fruits           0
# Amount_on_MeatProducts     0
# Amount_on_FishProducts     0
# Amount_on_SweetProducts    0
# Amount_on_GoldProds        0
# WebVisitsMonth             0
# Cmp3Accepted               0
# Cmp4Accepted               0
# Cmp5Accepted               0
# Cmp1Accepted               0
# Cmp2Accepted               0
# Any_Complain               0
# dtype: int64

# %%
TRAIN.dtypes
# Out:
# ID                          object
# Year_of_Birth                int64
# Education_Level             object
# Marital_Status              object
# Disposable_Income          float64
# No_of_Kids_in_home           int64
# No_of_Teen_in_home           int64
# Date_Customer               object
# Recency                      int64
# Discounted_Purchases         int64
# WebPurchases                 int64
# CatalogPurchases             int64
# StorePurchases               int64
# Amount_on_Wines              int64
# Amount_on_Fruits             int64
# Amount_on_MeatProducts       int64
# Amount_on_FishProducts       int64
# Amount_on_SweetProducts      int64
# Amount_on_GoldProds          int64
# WebVisitsMonth               int64
# Cmp3Accepted                 int64
# Cmp4Accepted                 int64
# Cmp5Accepted                 int64
# Cmp1Accepted                 int64
# Cmp2Accepted                 int64
# Any_Complain                 int64
# Response                     int64
# ...

# %%
train_copy = TRAIN

# %%
TRAIN = TRAIN.drop('ID', axis= 1)

# %%
TEST = TEST.drop('ID', axis= 1)

# %%
TRAIN = TRAIN.drop('Date_Customer', axis= 1)

# %%
TEST = TEST.drop('Date_Customer', axis= 1)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
led = LabelEncoder()

# %%
TRAIN['Marital_Status']=led.fit_transform(TRAIN['Marital_Status'])

# %%
TEST['Marital_Status']=led.fit_transform(TEST['Marital_Status'])

# %%
TRAIN['Education_Level'] = led.fit_transform(TRAIN['Education_Level'])

# %%
TEST['Education_Level'] = led.fit_transform(TEST['Education_Level'])

# %%
TRAIN
# Out:
#       Year_of_Birth  Education_Level  Marital_Status  Disposable_Income  \
# 0              1955                2               2            77504.4
# 1              1958                2               5            56784.0
# 2              1962                2               4           103714.8
# 3              1979                0               4            46311.6
# 4              1959                2               3            87486.0
# ...             ...              ...             ...                ...
# 1563           1970                2               3            52893.6
# 1564           1980                2               4            74190.0
# 1565           1952                3               3            80857.2
# 1566           1964                4               4            58701.6
# 1567           1970                2               5            27873.6
#
#       No_of_Kids_in_home  No_of_Teen_in_home  Recency  Discounted_Purchases  \
# ...

# %%
X = TRAIN.drop('Response', axis= 1)

# %%
y = TRAIN['Response']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train,y_test = train_test_split(X,y, test_size=0.25, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
mod = RandomForestClassifier()

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score
random_search = {'criterion':['entropy','gini'],
                'max_features':['auto', 'sqrt', 'log2', None],
                'max_depth':list}

# %%
gs.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False,
# ...

# %%
y_pred = gs.predict(x_test)

# %%
from sklearn.metrics import f1_score

# %%
f1_score(y_test , y_pred)
# Out:
# 0.41975308641975306
