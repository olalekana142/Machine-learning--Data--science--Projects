# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
train = pd.read_csv('test_lAUu6dG.csv')

# %%
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
train.shape
# Out:
# (367, 12)

# %%
train.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome      int64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# dtype: object

# %%
train['Gender'].value_counts(normalize = True).plot.bar(figsize = (20,10), title = 'Gender')
plt.show()

# %%
train['Married'].value_counts(normalize = True).plot.bar(figsize = (20,10), title = 'Married')
plt.show()

# %%
train['Credit_History'].value_counts(normalize = True).plot.bar(figsize = (20,10), title = 'Credit_History')
plt.show()

# %%
sns.distplot(train['ApplicantIncome'])
plt.show()
train['ApplicantIncome'].plot.box(figsize= (16,5))
plt.show()

# %%
train.boxplot(column='ApplicantIncome', by = 'Education')
plt.suptitle('')
# Out:
# Text(0.5, 0.98, '')

# %%
sns.distplot(train['CoapplicantIncome'])
plt.show()
train['CoapplicantIncome'].plot.box(figsize= (16,5))
plt.show()

# %%
train.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %% [markdown]
# ## We will consider these methods to fill the missing values

# %% [markdown]
# ## 1: For numerical variables : imputaion of mean or median

# %% [markdown]
# ## 2: For Categorical variables: imputation using mode

# %%
train['Gender'].fillna(train['Gender'].mode()[0], inplace = True)
train['Dependents'].fillna(train['Dependents'].mode()[0], inplace = True)
train['Self_Employed'].fillna(train['Self_Employed'].mode()[0], inplace = True)
train['Loan_Amount_Term'].fillna(train['Loan_Amount_Term'].mode()[0], inplace = True)
train['Credit_History'].fillna(train['Credit_History'].mode()[0], inplace = True)
train['LoanAmount'].fillna(train['LoanAmount'].median(), inplace = True)

# %%
train.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %% [markdown]
# # Due to the outliers in the datasets, we take the log transformation, removing the skewness, it does not affect the small values but redues the larger values

# %%
train['LoanAmount_log'] = np.log(train['LoanAmount'])
train['LoanAmount_log'].hist(bins=20)

# %%
test = train.drop('Loan_ID', axis= 1)

# %%
test=  pd.get_dummies(test)

# %%
traini = pd.read_csv('train_ctrUa4K.csv')

# %%
traini.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
traini.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
traini['Gender'].fillna(traini['Gender'].mode()[0], inplace = True)
traini['Married'].fillna(traini['Married'].mode()[0], inplace = True)
traini['Dependents'].fillna(traini['Dependents'].mode()[0], inplace = True)
traini['Self_Employed'].fillna(traini['Self_Employed'].mode()[0], inplace = True)
traini['Loan_Amount_Term'].fillna(traini['Loan_Amount_Term'].mode()[0], inplace = True)
traini['Credit_History'].fillna(traini['Credit_History'].mode()[0], inplace = True)
traini['LoanAmount'].fillna(traini['LoanAmount'].median(), inplace = True)

# %%
traini.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
traini['Married'].fillna(traini['Married'].mode()[0], inplace = True)

# %%
traini.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
traini['LoanAmount_log'] = np.log(train['LoanAmount'])
traini['LoanAmount_log'].hist(bins=20)

# %%
traini = traini.drop('Loan_ID', axis =1)

# %%
Xtrain = traini.drop('Loan_Status', axis = 1)

# %%
y = traini['Loan_Status']

# %%
y
# Out:
# 0      Y
# 1      N
# 2      Y
# 3      Y
# 4      Y
#       ..
# 609    Y
# 610    Y
# 611    Y
# 612    Y
# 613    N
# Name: Loan_Status, Length: 614, dtype: object

# %%
traini=  pd.get_dummies(traini)

# %%
traini.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History  LoanAmount_log  Gender_Female  Gender_Male  Married_No  \
# 0             1.0        4.700480              0            1           1
# 1             1.0        4.836282              0            1           0
# 2             1.0        5.337538              0            1           0
# 3             1.0        4.605170              0            1           0
# 4             1.0        4.356709              0            1           1
#
#    Married_Yes  ...  Dependents_3+  Education_Graduate  \
# ...

# %%
Xtrain=  pd.get_dummies(Xtrain)

# %%
Xtrain.isnull().sum()
# Out:
# ApplicantIncome              0
# CoapplicantIncome            0
# LoanAmount                   0
# Loan_Amount_Term             0
# Credit_History               0
# LoanAmount_log             247
# Gender_Female                0
# Gender_Male                  0
# Married_No                   0
# Married_Yes                  0
# Dependents_0                 0
# Dependents_1                 0
# Dependents_2                 0
# Dependents_3+                0
# Education_Graduate           0
# Education_Not Graduate       0
# Self_Employed_No             0
# Self_Employed_Yes            0
# Property_Area_Rural          0
# Property_Area_Semiurban      0
# Property_Area_Urban          0
# dtype: int64

# %%
Xtrain['LoanAmount_log'].fillna(Xtrain['LoanAmount_log'].mean(), inplace = True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
rt = LabelEncoder()

# %%
y= rt.fit_transform(y)

# %%
from sklearn.linear_model import LogisticRegression

# %%
ry = LogisticRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
xt,xr , yt,yr = train_test_split(Xtrain, y, random_state = 1)

# %%
ry.fit(xt,yt)
# Out:
# C:\Users\New Owner\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_predict= ry.predict(xr)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(yr,y_predict )
# Out:
# 0.7857142857142857

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
ran = RandomForestClassifier(random_state = 1000)

# %%
ran.fit(xt, yt)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=1000,
#                        verbose=0, warm_start=False)

# %%
ymodel = ran.predict(xr)

# %%
accuracy_score(yr,ymodel )
# Out:
# 0.7662337662337663
